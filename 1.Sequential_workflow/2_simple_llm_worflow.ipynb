# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
## create state

class LLMState(TypedDict):
    question : str
    answer : str

# %%
def llm_qa(state:LLMState )->LLMState:
    ## extract the question from the state
    question=state['question']

    ## form a prompt
    prompt=f'Answer te following question {question}'

    ## ask that question to the LLM
    answer=model.invoke(prompt).content

    ## update the answer in that state
    state['answer']=answer

    return state

# %%
## create graph
graph=StateGraph(LLMState)

## add nodes
graph.add_node('llm_qa',llm_qa)

## add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

## compile
workflow=graph.compile()

# %%
## execute
initial_state={'question':'How far is moon from the earth?'}
final_state=workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon is not constant, as the Moon orbits the Earth in an elliptical path.
#
# However, here are the key distances:
#
# *   **Average distance:** Approximately **384,400 kilometers (238,900 miles)**
# *   **Closest point (perigee):** Approximately **363,104 kilometers (225,623 miles)**
# *   **Farthest point (apogee):** Approximately **405,696 kilometers (252,088 miles)**
#
# So, the most commonly cited figure is the average distance of about 384,400 km.

# %%
## in Langchain
model.invoke('How far is moon from the earth?').content
# Out:
# 'The distance between the Earth and the Moon is not constant because the Moon orbits the Earth in an ellipse, not a perfect circle.\n\n**On average, the distance is approximately:**\n\n*   **384,400 kilometers (km)**\n*   **238,900 miles**\n\nHowever, it varies throughout its orbit:\n\n*   **At its closest point (perigee):** approximately 363,104 km (225,623 miles)\n*   **At its farthest point (apogee):** approximately 405,696 km (252,088 miles)\n\nThis means that light from the Moon takes about 1.2 to 1.3 seconds to reach Earth.'
